# %%
price=399
print(type(price))
# Out:
# <class 'int'>

# %%
a=100
b=0b1111
c=0o17
d=0xAF

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
print(int(15))
print(bin(15))
print(oct(15))
print(hex(15))
# Out:
# 15
# 0b1111
# 0o17
# 0xf

# %%
price=15
print(bin(price))
# Out:
# 0b1111
